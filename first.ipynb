# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaSaha23/ArkaSaha23/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a = int(input("Enter the number"))
b = int(input("Enter 2nd  number"))
c=a+b
print(c)
# Out:
# Enter the number6
# Enter 2nd  number7
# 13

# %%
for i in range(1,5):
    for j in range(1,i):
        print(j,end=" ")
    print()
# Out:
# 1
#  2
#  3
